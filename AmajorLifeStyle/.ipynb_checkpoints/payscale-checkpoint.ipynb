# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd
from copy import deepcopy
import os

file_to_load = "salaries-by-region.csv"

# %%
#read region data
region_data = pd.read_csv(file_to_load)

#Extract data by Region from the Master DF
Southern_Region = region_data.loc[region_data["Region"] == "Southern", :]

#List salary change over the lenght of mid-career by region; from school with hightest Starting_Mid to lowest Mid_90th
Southern_Sort = Southern_Region.sort_values(['Starting Median Salary', 'School Name'], ascending=[False, True])

#Clean DF to the areas of focus
South_Clean = Southern_Sort[["School Name", "Region", "Starting Median Salary", "Mid-Career Median Salary", "Mid-Career 90th Percentile Salary"]]
South_Clean = South_Clean.dropna()

#Index data for Region Column
South_Clean.set_index('Region', inplace=True)

#Add unique index value row
df = South_Clean.reset_index()
df.head()
# Out:
#      Region                                        School Name  \
# 0  Southern                                    Rice University
# 1  Southern                                    Duke University
# 2  Southern                    Georgia Institute of Technology
# 3  Southern                              Georgetown University
# 4  Southern  Virginia Polytechnic Institute and State Unive...
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0            $64,000.00              $110,000.00
# 1            $58,900.00              $106,000.00
# 2            $58,300.00              $106,000.00
# 3            $55,000.00              $110,000.00
# 4            $53,500.00               $95,400.00
#
#   Mid-Career 90th Percentile Salary
# 0                      $216,000.00
# 1                      $218,000.00
# 2                      $183,000.00
# 3                      $248,000.00
# 4                      $163,000.00

# %%
df.columns = ['REGION','SCHOOL NAME','STARTING AVG','MID CAREER AVG ','TOP 10% AVG']
df.head()
# Out:
#      REGION                                        SCHOOL NAME STARTING AVG  \
# 0  Southern                                    Rice University  $64,000.00
# 1  Southern                                    Duke University  $58,900.00
# 2  Southern                    Georgia Institute of Technology  $58,300.00
# 3  Southern                              Georgetown University  $55,000.00
# 4  Southern  Virginia Polytechnic Institute and State Unive...  $53,500.00
#
#   MID CAREER AVG    TOP 10% AVG
# 0    $110,000.00   $216,000.00
# 1    $106,000.00   $218,000.00
# 2    $106,000.00   $183,000.00
# 3    $110,000.00   $248,000.00
# 4     $95,400.00   $163,000.00

# %% [markdown]
# USE CHROMEDRIVER TO ACCESS BASE-URL TO BE USED

# %%
# https://splinter.readthedocs.io/en/latest/drivers/chrome.html
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
base_url = 'https://www.payscale.com/cost-of-living-calculator/'

# %% [markdown]
# APPEND THE PAGES RELATED TO EACH CITY/STATE WITHIN THE REGION TO THE BASE URL

# %%
#Create list of links
city_list= ['Georgia-Atlanta', 'Texas-Austin','North-Carolina-Charlotte', 'Texas-Dallas',\
            'Texas-Houston', 'Florida-Miami', 'Tennessee-Nashville', 'Florida-Orlando', 'North-Carolina-Raleigh', 'Florida-Tampa', 'District-of-Columbia-Washington']
count = 0
pages = []
for page in city_list:
    page_url = f"{base_url}{city_list[count]}"
    count = count + 1
    pages.append(page_url)
    print(page_url)
# Out:
# https://www.payscale.com/cost-of-living-calculator/Georgia-Atlanta
# https://www.payscale.com/cost-of-living-calculator/Texas-Austin
# https://www.payscale.com/cost-of-living-calculator/North-Carolina-Charlotte
# https://www.payscale.com/cost-of-living-calculator/Texas-Dallas
# https://www.payscale.com/cost-of-living-calculator/Texas-Houston
# https://www.payscale.com/cost-of-living-calculator/Florida-Miami
# https://www.payscale.com/cost-of-living-calculator/Tennessee-Nashville
# https://www.payscale.com/cost-of-living-calculator/Florida-Orlando
# https://www.payscale.com/cost-of-living-calculator/North-Carolina-Raleigh
# https://www.payscale.com/cost-of-living-calculator/Florida-Tampa
# https://www.payscale.com/cost-of-living-calculator/District-of-Columbia-Washington

# %%
headers = ['Median Home Price','Median Rent','Energy Bill','Phone Bill','Gas','Loaf of Bread', \
            'Gallon of Milk','Carton of Eggs','Bunch of Bananas','Hamburger',"Doctor's Visit",\
            'Dentist Visit','Optometrist Visit','Rx Drug','Veterinary Visit']

# %%
count = 0
lifestyle_df = pd.DataFrame()
for page in pages:
    browser.visit(page)
    south_region = browser.html
    southern_soup = bs(south_region, 'html.parser')
    values = []
    for info in southern_soup.find_all('div', class_='itemized__item-container'):   
        for v in info.find_all('div', class_='itemized__item-value'):
            value = v.text
            values.append(deepcopy(value))
        
    style_df = pd.DataFrame([{headers[x]:values[x] for x in range(len(headers))}])
    lifestyle_df = lifestyle_df.append(deepcopy(style_df))

# %%
#Create a column titled 'STATES', add the city_list values
df = pd.DataFrame(lifestyle_df)
df['STATES']= city_list

# %%
#Set index to STATES
Southern_data = df.set_index('STATES')
Southern_data
# Out:
#                                 Median Home Price       Median Rent  \
# STATES
# Georgia-Atlanta                          $327,568   $1,026 / month
# Texas-Austin                             $353,246   $1,107 / month
# North-Carolina-Charlotte                 $296,685  $929.39 / month
# Texas-Dallas                             $364,003   $1,140 / month
# Texas-Houston                            $363,656   $1,139 / month
# Florida-Miami                            $498,986   $1,563 / month
# Tennessee-Nashville                      $316,117  $990.26 / month
# Florida-Orlando                          $308,483  $966.34 / month
# North-Carolina-Raleigh                   $241,512  $756.55 / month
# Florida-Tampa                            $266,843  $835.90 / month
# District-of-Columbia-Washington          $859,866   $2,694 / month
#
#                                       Energy Bill        Phone Bill  \
# STATES
# Georgia-Atlanta                  $143.01 / month   $152.45 / month
# Texas-Austin                     $147.04 / month   $156.74 / month
# North-Carolina-Charlotte         $153.91 / month   $164.06 / month
# Texas-Dallas                     $174.87 / month   $186.40 / month
# Texas-Houston                    $185.43 / month   $197.66 / month
# Florida-Miami                    $165.31 / month   $176.22 / month
# Tennessee-Nashville              $150.73 / month   $160.67 / month
# Florida-Orlando                  $186.44 / month   $198.74 / month
# North-Carolina-Raleigh           $161.62 / month   $172.29 / month
# Florida-Tampa                    $194.99 / month   $207.85 / month
# District-of-Columbia-Washington  $162.13 / month   $172.82 / month
#
#                                              Gas Loaf of Bread Gallon of Milk  \
# STATES
# Georgia-Atlanta                  $2.64 / gallon          $3.50          $2.04
# Texas-Austin                     $2.44 / gallon          $2.92          $1.70
# North-Carolina-Charlotte         $2.53 / gallon          $3.12          $1.82
# Texas-Dallas                     $2.59 / gallon          $3.16          $1.84
# Texas-Houston                    $2.54 / gallon          $2.89          $1.68
# Florida-Miami                    $2.93 / gallon          $3.51          $2.04
# Tennessee-Nashville              $2.62 / gallon          $3.23          $1.88
# Florida-Orlando                  $2.45 / gallon          $3.40          $1.98
# North-Carolina-Raleigh           $2.39 / gallon          $3.77          $2.20
# Florida-Tampa                    $2.77 / gallon          $3.33          $1.94
# District-of-Columbia-Washington  $2.73 / gallon          $3.66          $2.13
#
#                                 Carton of Eggs Bunch of Bananas Hamburger  \
# STATES
# Georgia-Atlanta                          $1.90            $3.53     $4.46
# Texas-Austin                             $1.59            $2.95     $3.72
# North-Carolina-Charlotte                 $1.70            $3.15     $3.98
# Texas-Dallas                             $1.72            $3.19     $4.02
# Texas-Houston                            $1.57            $2.92     $3.68
# Florida-Miami                            $1.91            $3.54     $4.47
# Tennessee-Nashville                      $1.75            $3.26     $4.11
# Florida-Orlando                          $1.85            $3.43     $4.33
# North-Carolina-Raleigh                   $2.05            $3.80     $4.80
# Florida-Tampa                            $1.81            $3.36     $4.24
# District-of-Columbia-Washington          $1.99            $3.70     $4.66
#
#                                 Doctor's Visit Dentist Visit  \
# STATES
# Georgia-Atlanta                        $119.01       $102.24
# Texas-Austin                           $110.05        $94.54
# North-Carolina-Charlotte               $114.14        $98.06
# Texas-Dallas                           $112.04        $96.25
# Texas-Houston                          $100.97        $86.74
# Florida-Miami                          $107.39        $92.26
# Tennessee-Nashville                     $90.45        $77.70
# Florida-Orlando                         $97.65        $83.89
# North-Carolina-Raleigh                 $113.92        $97.87
# Florida-Tampa                          $108.83        $93.49
# District-of-Columbia-Washington        $106.84        $91.78
#
#                                 Optometrist Visit  Rx Drug Veterinary Visit
# STATES
# Georgia-Atlanta                           $111.52  $474.08           $52.50
# Texas-Austin                              $103.12  $438.35           $51.88
# North-Carolina-Charlotte                  $106.96  $454.67           $52.34
# Texas-Dallas                              $104.98  $446.29           $52.65
# Texas-Houston                              $94.61  $402.19           $48.64
# Florida-Miami                             $100.63  $427.77           $52.19
# Tennessee-Nashville                        $84.76  $360.30           $53.37
# Florida-Orlando                            $91.50  $388.96           $48.69
# North-Carolina-Raleigh                    $106.75  $453.79           $54.82
# Florida-Tampa                             $101.98  $433.50           $49.93
# District-of-Columbia-Washington           $100.11  $425.57           $50.44

# %%
#Prepare text for aggregation
for x in Southern_data:
    Southern_data[x] = Southern_data[x].str.replace("$","")
    Southern_data[x] = Southern_data[x].str.replace("month","")
    Southern_data[x] = Southern_data[x].str.replace("/","")
    Southern_data[x] = Southern_data[x].str.replace("gallon","")
    Southern_data[x] = Southern_data[x].str.replace(",","")
    Southern_data[x] = pd.to_numeric(Southern_data[x])

Southern_data.head()
# Out:
#                           Median Home Price  Median Rent  Energy Bill  \
# STATES
# Georgia-Atlanta                      327568      1026.00       143.01
# Texas-Austin                         353246      1107.00       147.04
# North-Carolina-Charlotte             296685       929.39       153.91
# Texas-Dallas                         364003      1140.00       174.87
# Texas-Houston                        363656      1139.00       185.43
#
#                           Phone Bill   Gas  Loaf of Bread  Gallon of Milk  \
# STATES
# Georgia-Atlanta               152.45  2.64           3.50            2.04
# Texas-Austin                  156.74  2.44           2.92            1.70
# North-Carolina-Charlotte      164.06  2.53           3.12            1.82
# Texas-Dallas                  186.40  2.59           3.16            1.84
# Texas-Houston                 197.66  2.54           2.89            1.68
#
#                           Carton of Eggs  Bunch of Bananas  Hamburger  \
# STATES
# Georgia-Atlanta                     1.90              3.53       4.46
# Texas-Austin                        1.59              2.95       3.72
# North-Carolina-Charlotte            1.70              3.15       3.98
# Texas-Dallas                        1.72              3.19       4.02
# Texas-Houston                       1.57              2.92       3.68
#
#                           Doctor's Visit  Dentist Visit  Optometrist Visit  \
# STATES
# Georgia-Atlanta                   119.01         102.24             111.52
# Texas-Austin                      110.05          94.54             103.12
# North-Carolina-Charlotte          114.14          98.06             106.96
# Texas-Dallas                      112.04          96.25             104.98
# Texas-Houston                     100.97          86.74              94.61
#
#                           Rx Drug  Veterinary Visit
# STATES
# Georgia-Atlanta            474.08             52.50
# Texas-Austin               438.35             51.88
# North-Carolina-Charlotte   454.67             52.34
# Texas-Dallas               446.29             52.65
# Texas-Houston              402.19             48.64

# %%
#Renamed columns
Southern_data.columns = ['MORTGAGE','RENT','ELECTRICITY','PHONE','GAS','BREAD','MILK','EGGS','BANANAS','POLTRY','PHYSICIAN', 'DENTIST','OPTOMISTRIST', 'RX','VET']
Southern_data['HLTH & WELL']=Southern_data['PHYSICIAN'] + Southern_data['DENTIST'] + Southern_data['OPTOMISTRIST'] + Southern_data['RX']
Southern_data['EAT-IN']=Southern_data['BREAD'] + Southern_data['MILK'] + Southern_data['BANANAS'] + Southern_data['POLTRY']
Southern_data = Southern_data.drop(['BREAD','MILK','EGGS','BANANAS','POLTRY','PHYSICIAN', 'DENTIST', 'OPTOMISTRIST','RX'], axis=1)
Southern_data
# Out:
#                                  MORTGAGE     RENT  ELECTRICITY   PHONE   GAS  \
# STATES
# Georgia-Atlanta                    327568  1026.00       143.01  152.45  2.64
# Texas-Austin                       353246  1107.00       147.04  156.74  2.44
# North-Carolina-Charlotte           296685   929.39       153.91  164.06  2.53
# Texas-Dallas                       364003  1140.00       174.87  186.40  2.59
# Texas-Houston                      363656  1139.00       185.43  197.66  2.54
# Florida-Miami                      498986  1563.00       165.31  176.22  2.93
# Tennessee-Nashville                316117   990.26       150.73  160.67  2.62
# Florida-Orlando                    308483   966.34       186.44  198.74  2.45
# North-Carolina-Raleigh             241512   756.55       161.62  172.29  2.39
# Florida-Tampa                      266843   835.90       194.99  207.85  2.77
# District-of-Columbia-Washington    859866  2694.00       162.13  172.82  2.73
#
#                                    VET  HLTH & WELL  EAT-IN
# STATES
# Georgia-Atlanta                  52.50       806.85   13.53
# Texas-Austin                     51.88       746.06   11.29
# North-Carolina-Charlotte         52.34       773.83   12.07
# Texas-Dallas                     52.65       759.56   12.21
# Texas-Houston                    48.64       684.51   11.17
# Florida-Miami                    52.19       728.05   13.56
# Tennessee-Nashville              53.37       613.21   12.48
# Florida-Orlando                  48.69       662.00   13.14
# North-Carolina-Raleigh           54.82       772.33   14.57
# Florida-Tampa                    49.93       737.80   12.87
# District-of-Columbia-Washington  50.44       724.30   14.15

# %%
#Create column titled "REGION" and assign "Southern" values for each row.
region = 'Southern'
Southern_data['REGION'] = [region for _ in range(len(Southern_data))]
Southern_data
# Out:
#                                  MORTGAGE     RENT  ELECTRICITY   PHONE   GAS  \
# STATES
# Georgia-Atlanta                    327568  1026.00       143.01  152.45  2.64
# Texas-Austin                       353246  1107.00       147.04  156.74  2.44
# North-Carolina-Charlotte           296685   929.39       153.91  164.06  2.53
# Texas-Dallas                       364003  1140.00       174.87  186.40  2.59
# Texas-Houston                      363656  1139.00       185.43  197.66  2.54
# Florida-Miami                      498986  1563.00       165.31  176.22  2.93
# Tennessee-Nashville                316117   990.26       150.73  160.67  2.62
# Florida-Orlando                    308483   966.34       186.44  198.74  2.45
# North-Carolina-Raleigh             241512   756.55       161.62  172.29  2.39
# Florida-Tampa                      266843   835.90       194.99  207.85  2.77
# District-of-Columbia-Washington    859866  2694.00       162.13  172.82  2.73
#
#                                    VET  HLTH & WELL  EAT-IN    REGION
# STATES
# Georgia-Atlanta                  52.50       806.85   13.53  Southern
# Texas-Austin                     51.88       746.06   11.29  Southern
# North-Carolina-Charlotte         52.34       773.83   12.07  Southern
# Texas-Dallas                     52.65       759.56   12.21  Southern
# Texas-Houston                    48.64       684.51   11.17  Southern
# Florida-Miami                    52.19       728.05   13.56  Southern
# Tennessee-Nashville              53.37       613.21   12.48  Southern
# Florida-Orlando                  48.69       662.00   13.14  Southern
# North-Carolina-Raleigh           54.82       772.33   14.57  Southern
# Florida-Tampa                    49.93       737.80   12.87  Southern
# District-of-Columbia-Washington  50.44       724.30   14.15  Southern

# %%
#Reorder columns
Southern_data = Southern_data[['MORTGAGE', 'RENT', 'ELECTRICITY','GAS', 'EAT-IN','PHONE','HLTH & WELL', 'VET', 'REGION']]
Southern_data
# Out:
#                                  MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN  \
# STATES
# Georgia-Atlanta                    327568  1026.00       143.01  2.64   13.53
# Texas-Austin                       353246  1107.00       147.04  2.44   11.29
# North-Carolina-Charlotte           296685   929.39       153.91  2.53   12.07
# Texas-Dallas                       364003  1140.00       174.87  2.59   12.21
# Texas-Houston                      363656  1139.00       185.43  2.54   11.17
# Florida-Miami                      498986  1563.00       165.31  2.93   13.56
# Tennessee-Nashville                316117   990.26       150.73  2.62   12.48
# Florida-Orlando                    308483   966.34       186.44  2.45   13.14
# North-Carolina-Raleigh             241512   756.55       161.62  2.39   14.57
# Florida-Tampa                      266843   835.90       194.99  2.77   12.87
# District-of-Columbia-Washington    859866  2694.00       162.13  2.73   14.15
#
#                                   PHONE  HLTH & WELL    VET    REGION
# STATES
# Georgia-Atlanta                  152.45       806.85  52.50  Southern
# Texas-Austin                     156.74       746.06  51.88  Southern
# North-Carolina-Charlotte         164.06       773.83  52.34  Southern
# Texas-Dallas                     186.40       759.56  52.65  Southern
# Texas-Houston                    197.66       684.51  48.64  Southern
# Florida-Miami                    176.22       728.05  52.19  Southern
# Tennessee-Nashville              160.67       613.21  53.37  Southern
# Florida-Orlando                  198.74       662.00  48.69  Southern
# North-Carolina-Raleigh           172.29       772.33  54.82  Southern
# Florida-Tampa                    207.85       737.80  49.93  Southern
# District-of-Columbia-Washington  172.82       724.30  50.44  Southern

# %%
#Convert DF to CSV
Southern_data.to_csv("southern.csv")

# %%
Southern_data.mean(axis = 0)
# Out:
# MORTGAGE       381542.272727
# RENT             1195.221818
# ELECTRICITY       165.952727
# GAS                 2.602727
# EAT-IN             12.821818
# PHONE             176.900000
# HLTH & WELL       728.045455
# VET                51.586364
# dtype: float64

# %%
#Transpose the DataFrame
southern_avg = pd.DataFrame(Southern_data.mean())
southern_avg_t = southern_avg.T
southern_avg_t
# Out:
#         MORTGAGE         RENT  ELECTRICITY       GAS     EAT-IN  PHONE  \
# 0  381542.272727  1195.221818   165.952727  2.602727  12.821818  176.9
#
#    HLTH & WELL        VET
# 0   728.045455  51.586364

# %% [markdown]
# Loading all the CSV's cleaned from teammates and creating one complete DataFrame

# %%
#Load all csv to be merged
mid_west_df = pd.read_csv("mid_west.csv")
southern_df_csv = pd.read_csv("southern.csv")
cali_df = pd.read_csv("cali.csv")
western_df= pd.read_csv("westerns.csv")
north_east = pd.read_csv('Northeast.csv')

# %%
#Append mid_west & southern csv files
Mid_South = mid_west_df.append(southern_df_csv,ignore_index = True)
Mid_South.head()
# Out:
#                  STATES  MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN   PHONE  \
# 0      Illinois-Chicago    539932  1691.00       151.23  3.30   15.89  161.21
# 1       Ohio-Cincinnati    264414   828.29       159.95  2.63   13.40  170.50
# 2        Ohio-Cleveland    306401   959.82       175.54  2.68   16.32  187.12
# 3      Michigan-Detroit    326527  1023.00       171.18  2.82   13.32  182.47
# 4  Missouri-Kansas-City    319587  1001.00       180.74  2.57   14.71  192.66
#
#    HLTH & WELL    VET    REGION
# 0       760.32  59.09  Mid-West
# 1       738.55  52.45  Mid-West
# 2       759.56  54.56  Mid-West
# 3       707.02  50.03  Mid-West
# 4       742.30  53.48  Mid-West

# %%
#Append western & north_east csv files
Western_NE = western_df.append(north_east,ignore_index = True)
Western_NE
# Out:
#                       STATES  MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN  \
# 0         Washington-Seattle    673874  2111.00       206.39  3.47   16.31
# 1            Oregon-Portland    620783  1945.00       130.77  2.78   14.82
# 2            Arizona-Phoenix    330344  1035.00       161.12  2.39   12.53
# 3            Colorado-Denver    463245  1451.00       156.76  2.75   12.60
# 4       Massachusetts-Boston    717943  2249.00       236.57  2.89   15.52
# 5          New-York-New-York   1628124  5100.00       210.08  3.47   18.81
# 6    Pennsylvania-Pittsburgh    317505   994.61       184.43  2.78   16.21
# 7  Pennsylvania-Philadelphia    449365  1408.00       208.74  3.00   17.05
# 8         Maryland-Baltimore    509743  1597.00       179.56  2.69   15.74
#
#     PHONE  HLTH & WELL    VET     REGION
# 0  220.00       932.20  69.64    Western
# 1  139.40       803.85  60.53    Western
# 2  171.75       733.29  48.23    Western
# 3  167.10       790.34  55.28    Western
# 4  252.17      1014.76  66.81  Northeast
# 5  223.94       863.15  76.07  Northeast
# 6  196.59       704.03  50.13  Northeast
# 7  222.51       793.34  55.18  Northeast
# 8  191.41       687.52  54.40  Northeast

# %%
#Append  all four df's using the variabes created
Sth_West_Mid_NE = Mid_South.append(Western_NE,ignore_index = True)
Sth_West_Mid_NE.head()
# Out:
#                  STATES  MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN   PHONE  \
# 0      Illinois-Chicago    539932  1691.00       151.23  3.30   15.89  161.21
# 1       Ohio-Cincinnati    264414   828.29       159.95  2.63   13.40  170.50
# 2        Ohio-Cleveland    306401   959.82       175.54  2.68   16.32  187.12
# 3      Michigan-Detroit    326527  1023.00       171.18  2.82   13.32  182.47
# 4  Missouri-Kansas-City    319587  1001.00       180.74  2.57   14.71  192.66
#
#    HLTH & WELL    VET    REGION
# 0       760.32  59.09  Mid-West
# 1       738.55  52.45  Mid-West
# 2       759.56  54.56  Mid-West
# 3       707.02  50.03  Mid-West
# 4       742.30  53.48  Mid-West

# %%
#Append all five df's
NE_Sth_West_Mid_Cali = Sth_West_Mid_NE.append(cali_df,ignore_index = True)
NE_Sth_West_Mid_Cali.head()
# Out:
#                  STATES  MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN   PHONE  \
# 0      Illinois-Chicago    539932  1691.00       151.23  3.30   15.89  161.21
# 1       Ohio-Cincinnati    264414   828.29       159.95  2.63   13.40  170.50
# 2        Ohio-Cleveland    306401   959.82       175.54  2.68   16.32  187.12
# 3      Michigan-Detroit    326527  1023.00       171.18  2.82   13.32  182.47
# 4  Missouri-Kansas-City    319587  1001.00       180.74  2.57   14.71  192.66
#
#    HLTH & WELL    VET    REGION
# 0       760.32  59.09  Mid-West
# 1       738.55  52.45  Mid-West
# 2       759.56  54.56  Mid-West
# 3       707.02  50.03  Mid-West
# 4       742.30  53.48  Mid-West

# %%
NE_Sth_West_Mid_Cali.to_csv('LifstyleByRegion.csv')

# %%
apartment_url = 'https://mentalfloss.com/article/81296/average-cost-one-bedroom-apartments-50-major-us-cities'
count=0
Apartment_df = pd.DataFrame()
apartmentlist=[]
browser.visit(apartment_url)
apartm = browser.html
apartm_soup = bs(apartm, 'html.parser')
table = apartm_soup.find('tbody')
for info in table.find_all('tr'):
    values=info.text
    apartmentlist.append(values)

ApartmentInfo=Apartment_df.append(apartmentlist)

# %%
ApartmentInfo = pd.DataFrame(ApartmentInfo)
ApartmentInfo.head()
# Out:
#                                       0
# 0  \nSan Francisco, California\n$3600\n
# 1       \nSan Jose, California\n$2536\n
# 2         \nNew York, New York\n$2200\n
# 3             \nWashington, DC\n$2172\n
# 4      \nBoston, Massachusetts\n$2025\n

# %%
new = ApartmentInfo[0].str.split("\n", n = 3, expand = True)
Apt_df = new[[1,2]]
Apt_df.head()
# Out:
#                            1      2
# 0  San Francisco, California  $3600
# 1       San Jose, California  $2536
# 2         New York, New York  $2200
# 3             Washington, DC  $2172
# 4      Boston, Massachusetts  $2025

# %% [markdown]
# From original DF(Apt_df), split Index1 by ',' into two columns and name it (Apt1_df). From apt_df, we split column 1(index1) at the comma so that the city and state are 2 different columns. Then we put the state and city into 2 different columns within a new dataframe. Then we pick column 2(index2) from the Apt_df and assign it to column2(index2) in the new dataframe. So, now we have a total of 3 columns in the new dataframe.

# %%
new_df = Apt_df[1].str.split(",", n=1, expand=True)
new_df[2] = Apt_df[2]
new_df[2] = Apt_df[2].str.replace("$","")
new_df.columns=['CITY', 'STATE', '1BEDROOM']
new_df.head()
# Out:
#             CITY           STATE 1BEDROOM
# 0  San Francisco      California     3600
# 1       San Jose      California     2536
# 2       New York        New York     2200
# 3     Washington              DC     2172
# 4         Boston   Massachusetts     2025

# %%
new_df.to_csv('OnebedroomApt.csv')
new_df.head()
# Out:
#             CITY           STATE 1BEDROOM
# 0  San Francisco      California     3600
# 1       San Jose      California     2536
# 2       New York        New York     2200
# 3     Washington              DC     2172
# 4         Boston   Massachusetts     2025

# %%
CollegebyState = pd.read_csv('UScollegesUniversitiesByState.csv', encoding='ISO-8859-1')
CollegebyState.head()
# Out:
#                     Name       Location  Rank  \
# 0   Princeton University  Princeton, NJ     1
# 1     Harvard University  Cambridge, MA     2
# 2  University of Chicago    Chicago, IL     3
# 3        Yale University  New Haven, CT     3
# 4    Columbia University   New York, NY     5
#
#                                          Description Tuition and fees  \
# 0  Princeton, the fourth-oldest college in the Un...         $45,320
# 1  Harvard is located in Cambridge, Massachusetts...         $47,074
# 2  The University of Chicago, situated in Chicago...         $52,491
# 3  Yale University, located in New Haven, Connect...         $49,480
# 4  Columbia University, located in Manhattan's Mo...         $55,056
#
#   In-state Undergrad Enrollment
# 0      NaN                5,402
# 1      NaN                6,699
# 2      NaN                5,844
# 3      NaN                5,532
# 4      NaN                6,102

# %%
UScollegesUnivByState_df = pd.read_csv("UScollegesUniversitiesByState.csv", encoding = "ISO-8859-1")
UScollegesUnivByState_df

new_df = UScollegesUnivByState_df["Location"].str.split(",", n=1, expand=True)
new_df[0]
# Out:
# 0            Princeton
# 1            Cambridge
# 2              Chicago
# 3            New Haven
# 4             New York
#             ...
# 226    North Dartmouth
# 227          St. Louis
# 228         Greensboro
# 229        Hattiesburg
# 230              Logan
# Name: 0, Length: 231, dtype: object

# %%
UScollegesUnivByState_df["City"] = new_df[0]
UScollegesUnivByState_df["State"] = new_df[1]
UScollegesUnivByState_df.drop(columns = ['Location'], inplace=True, axis=1)
UScollegesUnivByState_df.head()
# Out:
#                     Name  Rank  \
# 0   Princeton University     1
# 1     Harvard University     2
# 2  University of Chicago     3
# 3        Yale University     3
# 4    Columbia University     5
#
#                                          Description Tuition and fees  \
# 0  Princeton, the fourth-oldest college in the Un...         $45,320
# 1  Harvard is located in Cambridge, Massachusetts...         $47,074
# 2  The University of Chicago, situated in Chicago...         $52,491
# 3  Yale University, located in New Haven, Connect...         $49,480
# 4  Columbia University, located in Manhattan's Mo...         $55,056
#
#   In-state Undergrad Enrollment       City State
# 0      NaN                5,402  Princeton    NJ
# 1      NaN                6,699  Cambridge    MA
# 2      NaN                5,844    Chicago    IL
# 3      NaN                5,532  New Haven    CT
# 4      NaN                6,102   New York    NY

# %%
UScollegesUnivByState_df.drop(columns = ['Description', 'In-state', 'Undergrad Enrollment'], inplace=True, axis=1)
UScollegesUnivByState_df.head()
# Out:
#                     Name  Rank Tuition and fees       City State
# 0   Princeton University     1         $45,320   Princeton    NJ
# 1     Harvard University     2         $47,074   Cambridge    MA
# 2  University of Chicago     3         $52,491     Chicago    IL
# 3        Yale University     3         $49,480   New Haven    CT
# 4    Columbia University     5         $55,056    New York    NY

# %%
UScollegesUnivByState_df.to_csv("StateCollegeUniversity.csv")

# %%
Pay_Sch_Reg = pd.read_csv('payscale_school_region.csv', encoding='ISO-8859-1')
Pay_Sch_Reg.head()
# Out:
#    Unnamed: 0  MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN   PHONE  \
# 0           0    247758   776.12       154.08  2.18   13.32  164.24
# 1           1    247758   776.12       154.08  2.18   13.32  164.24
# 2           2    247758   776.12       154.08  2.18   13.32  164.24
# 3           3    259903   814.16       183.42  2.50   14.38  195.52
# 4           4    463245  1451.00       156.76  2.75   14.37  167.10
#
#    HLTH & WELL    VET           CITY      STATE  \
# 0       680.75  46.79  Oklahoma City   Oklahoma
# 1       680.75  46.79  Oklahoma City   Oklahoma
# 2       680.75  46.79  Oklahoma City   Oklahoma
# 3       654.49  48.02      Lafayette  Louisiana
# 4       790.34  55.28         Denver   Colorado
#
#                                  School Name    REGION Starting Median Salary  \
# 0                     University-of-Oklahoma  Southern            $44,700.00-
# 1                  Oklahoma-State-University  Southern            $42,800.00-
# 2                   Oklahoma-City-University  Southern            $40,000.00-
# 3  University-of-Louisiana-(UL)-at-Lafayette  Southern            $41,100.00-
# 4            University-of-Colorado---Denver   Western            $46,100.00-
#
#   Mid-Career Median Salary Mid-Career 10th Percentile Salary  \
# 0              $82,900.00-                       $41,200.00-
# 1              $80,700.00-                       $40,100.00-
# 2              $64,300.00-                               NaN
# 3              $76,300.00-                       $42,000.00-
# 4              $84,400.00-                       $46,400.00-
#
#   Mid-Career 25th Percentile Salary Mid-Career 75th Percentile Salary  \
# 0                       $60,300.00-                      $114,000.00-
# 1                       $56,500.00-                      $114,000.00-
# 2                       $45,400.00-                       $80,600.00-
# 3                       $54,500.00-                      $107,000.00-
# 4                       $58,600.00-                      $105,000.00-
#
#   Mid-Career 90th Percentile Salary  \
# 0                      $167,000.00-
# 1                      $151,000.00-
# 2                               NaN
# 3                      $163,000.00-
# 4                      $144,000.00-
#
#                                                  url
# 0  https://www.payscale.com/cost-of-living-calcul...
# 1  https://www.payscale.com/cost-of-living-calcul...
# 2  https://www.payscale.com/cost-of-living-calcul...
# 3  https://www.payscale.com/cost-of-living-calcul...
# 4  https://www.payscale.com/cost-of-living-calcul...

# %%
Pay_Sch_Reg.dtypes
# Out:
# Unnamed: 0                             int64
# MORTGAGE                               int64
# RENT                                 float64
# ELECTRICITY                          float64
# GAS                                  float64
# EAT-IN                               float64
# PHONE                                float64
# HLTH & WELL                          float64
# VET                                  float64
# CITY                                  object
# STATE                                 object
# School Name                           object
# REGION                                object
# Starting Median Salary                object
# Mid-Career Median Salary              object
# Mid-Career 10th Percentile Salary     object
# Mid-Career 25th Percentile Salary     object
# Mid-Career 75th Percentile Salary     object
# Mid-Career 90th Percentile Salary     object
# url                                   object
# dtype: object

# %%
Pay_Sch_Reg = Pay_Sch_Reg.drop(['Unnamed: 0','Mid-Career 10th Percentile Salary','Mid-Career 25th Percentile Salary','Mid-Career 75th Percentile Salary','url'], axis=1)
Pay_Sch_Reg
# Out:
#      MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN   PHONE  HLTH & WELL    VET  \
# 0      247758   776.12       154.08  2.18   13.32  164.24       680.75  46.79
# 1      247758   776.12       154.08  2.18   13.32  164.24       680.75  46.79
# 2      247758   776.12       154.08  2.18   13.32  164.24       680.75  46.79
# 3      259903   814.16       183.42  2.50   14.38  195.52       654.49  48.02
# 4      463245  1451.00       156.76  2.75   14.37  167.10       790.34  55.28
# ..        ...      ...          ...   ...     ...     ...          ...    ...
# 160    244957   767.34       208.74  3.00   17.05  222.51       793.34  55.18
# 161    286622   897.86       120.21  2.66   14.12  128.14       768.57  53.22
# 162    311953   977.21       216.11  2.47   13.19  230.37       683.01  50.23
# 163    237695   744.60       166.99  2.26   12.57  178.01       672.51  51.83
# 164    474696  1487.00       149.72  3.20   17.13  159.60       778.34  56.15
#
#               CITY         STATE  \
# 0    Oklahoma City      Oklahoma
# 1    Oklahoma City      Oklahoma
# 2    Oklahoma City      Oklahoma
# 3        Lafayette     Louisiana
# 4           Denver      Colorado
# ..             ...           ...
# 160        Chester  Pennsylvania
# 161        Lincoln      Nebraska
# 162       Beaumont         Texas
# 163     Cookeville     Tennessee
# 164     Sacramento    California
#
#                                         School Name        REGION  \
# 0                            University-of-Oklahoma      Southern
# 1                         Oklahoma-State-University      Southern
# 2                          Oklahoma-City-University      Southern
# 3         University-of-Louisiana-(UL)-at-Lafayette      Southern
# 4                   University-of-Colorado---Denver       Western
# ..                                              ...           ...
# 160                              Widener-University  Northeastern
# 161                          University-of-Nebraska    Midwestern
# 162                                Lamar-University      Southern
# 163              Tennessee-Technological-University      Southern
# 164  California-State-University,-Sacramento-(CSUS)    California
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $44,700.00-              $82,900.00-
# 1              $42,800.00-              $80,700.00-
# 2              $40,000.00-              $64,300.00-
# 3              $41,100.00-              $76,300.00-
# 4              $46,100.00-              $84,400.00-
# ..                     ...                      ...
# 160            $52,900.00-              $83,400.00-
# 161            $45,700.00-              $80,900.00-
# 162            $46,500.00-              $79,400.00-
# 163            $46,200.00-              $80,000.00-
# 164            $47,800.00-              $82,400.00-
#
#     Mid-Career 90th Percentile Salary
# 0                        $167,000.00-
# 1                        $151,000.00-
# 2                                 NaN
# 3                        $163,000.00-
# 4                        $144,000.00-
# ..                                ...
# 160                      $138,000.00-
# 161                      $156,000.00-
# 162                      $158,000.00-
# 163                      $121,000.00-
# 164                      $154,000.00-
#
# [165 rows x 15 columns]

# %%
Pay_Sch_Reg['Starting Median Salary'] = Pay_Sch_Reg['Starting Median Salary'].str.replace("$","")
Pay_Sch_Reg['Starting Median Salary'] = Pay_Sch_Reg['Starting Median Salary'].str.replace(",","")
Pay_Sch_Reg['Starting Median Salary'] = Pay_Sch_Reg['Starting Median Salary'].str.replace("-","")


Pay_Sch_Reg['Mid-Career Median Salary'] = Pay_Sch_Reg['Mid-Career Median Salary'].str.replace("$","")
Pay_Sch_Reg['Mid-Career Median Salary'] = Pay_Sch_Reg['Mid-Career Median Salary'].str.replace(",","")
Pay_Sch_Reg['Mid-Career Median Salary'] = Pay_Sch_Reg['Mid-Career Median Salary'].str.replace("-","")


Pay_Sch_Reg['Mid-Career 90th Percentile Salary'] = Pay_Sch_Reg['Mid-Career 90th Percentile Salary'].str.replace("$","")
Pay_Sch_Reg['Mid-Career 90th Percentile Salary'] = Pay_Sch_Reg['Mid-Career 90th Percentile Salary'].str.replace(",","")
Pay_Sch_Reg['Mid-Career 90th Percentile Salary'] = Pay_Sch_Reg['Mid-Career 90th Percentile Salary'].str.replace("-","")


# Pay_Sch_Reg['School Name'] = Pay_Sch_Reg['School Name'].str.replace("-","")



Pay_Sch_Reg.head()
# Out:
#    MORTGAGE     RENT  ELECTRICITY   GAS  EAT-IN   PHONE  HLTH & WELL    VET  \
# 0    247758   776.12       154.08  2.18   13.32  164.24       680.75  46.79
# 1    247758   776.12       154.08  2.18   13.32  164.24       680.75  46.79
# 2    247758   776.12       154.08  2.18   13.32  164.24       680.75  46.79
# 3    259903   814.16       183.42  2.50   14.38  195.52       654.49  48.02
# 4    463245  1451.00       156.76  2.75   14.37  167.10       790.34  55.28
#
#             CITY      STATE                                School Name  \
# 0  Oklahoma City   Oklahoma                     University-of-Oklahoma
# 1  Oklahoma City   Oklahoma                  Oklahoma-State-University
# 2  Oklahoma City   Oklahoma                   Oklahoma-City-University
# 3      Lafayette  Louisiana  University-of-Louisiana-(UL)-at-Lafayette
# 4         Denver   Colorado            University-of-Colorado---Denver
#
#      REGION Starting Median Salary Mid-Career Median Salary  \
# 0  Southern               44700.00                 82900.00
# 1  Southern               42800.00                 80700.00
# 2  Southern               40000.00                 64300.00
# 3  Southern               41100.00                 76300.00
# 4   Western               46100.00                 84400.00
#
#   Mid-Career 90th Percentile Salary
# 0                         167000.00
# 1                         151000.00
# 2                               NaN
# 3                         163000.00
# 4                         144000.00

# %%
Pay_Sch_Reg.to_csv("Pay_Sch_Reg_clean.csv")

# %%
apt_info=pd.read_csv('OnebedroomApt.csv')
apt_info.head()
# Out:
#    Unnamed: 0           CITY           STATE  1BEDROOM
# 0           0  San Francisco      California      3600
# 1           1       San Jose      California      2536
# 2           2       New York        New York      2200
# 3           3     Washington              DC      2172
# 4           4         Boston   Massachusetts      2025

# %%
apt_info = apt_info.drop(columns=['Unnamed: 0'], axis=1)
apt_info
# Out:
#                 CITY            STATE  1BEDROOM
# 0      San Francisco       California      3600
# 1           San Jose       California      2536
# 2           New York         New York      2200
# 3         Washington               DC      2172
# 4             Boston    Massachusetts      2025
# 5        Los Angeles       California      2014
# 6              Miami          Florida      2000
# 7         Pittsburgh     Pennsylvania      1850
# 8           Honolulu           Hawaii      1795
# 9            Seattle       Washington      1795
# 10         San Diego       California      1760
# 11           Anaheim       California      1606
# 12           Chicago         Illinois      1595
# 13            Denver         Colorado      1436
# 14       Minneapolis        Minnesota      1435
# 15         Nashville        Tennessee      1395
# 16           Atlanta          Georgia      1387
# 17           Houston            Texas      1308
# 18       New Orleans        Louisiana      1298
# 19      Philadelphia     Pennsylvania      1295
# 20            Dallas            Texas      1271
# 21         Charlotte   North Carolina      1265
# 22         Baltimore         Maryland      1175
# 23             Tampa          Florida      1100
# 24            Austin            Texas      1100
# 25          Portland           Oregon      1095
# 26         Anchorage           Alaska       995
# 27        Sacramento       California       995
# 28    Virginia Beach         Virginia       975
# 29           Phoenix          Arizona       909
# 30      Jacksonville          Florida       896
# 31         Las Vegas           Nevada       875
# 32            Newark       New Jersey       850
# 33           Memphis        Tennessee       835
# 34       San Antonio            Texas       830
# 35       Kansas City         Missouri       795
# 36             Omaha         Nebraska       759
# 37  Colorado Springs         Colorado       750
# 38         Milwaukee        Wisconsin       750
# 39        Louisville         Kentucky       750
# 40          Columbus             Ohio       750
# 41      Indianapolis          Indiana       732
# 42       Albuquerque       New Mexico       715
# 43         St. Louis         Missouri       700
# 44     Oklahoma City         Oklahoma       650
# 45           El Paso            Texas       600
# 46            Tuscon          Arizona       560
# 47           Detroit         Michigan       550
# 48         Cleveland             Ohio       525
# 49           Wichita           Kansas       470

# %%
apt_dict = apt_info.to_dict('records')
apt_dict
# Out:
# [{'CITY': 'San Francisco', 'STATE': ' California', '1BEDROOM': 3600},
#  {'CITY': 'San Jose', 'STATE': ' California', '1BEDROOM': 2536},
#  {'CITY': 'New York', 'STATE': ' New York', '1BEDROOM': 2200},
#  {'CITY': 'Washington', 'STATE': ' DC', '1BEDROOM': 2172},
#  {'CITY': 'Boston', 'STATE': ' Massachusetts', '1BEDROOM': 2025},
#  {'CITY': 'Los Angeles', 'STATE': ' California', '1BEDROOM': 2014},
#  {'CITY': 'Miami', 'STATE': ' Florida', '1BEDROOM': 2000},
#  {'CITY': 'Pittsburgh', 'STATE': ' Pennsylvania', '1BEDROOM': 1850},
#  {'CITY': 'Honolulu', 'STATE': ' Hawaii', '1BEDROOM': 1795},
#  {'CITY': 'Seattle', 'STATE': ' Washington', '1BEDROOM': 1795},
#  {'CITY': 'San Diego', 'STATE': ' California', '1BEDROOM': 1760},
#  {'CITY': 'Anaheim', 'STATE': ' California', '1BEDROOM': 1606},
#  {'CITY': 'Chicago', 'STATE': ' Illinois', '1BEDROOM': 1595},
#  {'CITY': 'Denver', 'STATE': ' Colorado', '1BEDROOM': 1436},
#  {'CITY': 'Minneapolis', 'STATE': ' Minnesota', '1BEDROOM': 1435},
#  {'CITY': 'Nashville', 'STATE': ' Tennessee', '1BEDROOM': 1395},
#  {'CITY': 'Atlanta', 'STATE': ' Georgia', '1BEDROOM': 1387},
#  {'CITY': 'Houston', 'STATE': ' Texas', '1BEDROOM': 1308},
#  {'CITY': 'New Orleans', 'STATE': ' Louisiana', '1BEDROOM': 1298},
#  {'CITY': 'Philadelphia', 'STATE': ' Pennsylvania', '1BEDROOM': 1295},
#  {'CITY': 'Dallas', 'STATE': ' Texas', '1BEDROOM': 1271},
#  {'CITY': 'Charlotte', 'STATE': ' North Carolina', '1BEDROOM': 1265},
#  {'CITY': 'Baltimore', 'STATE': ' Maryland', '1BEDROOM': 1175},
#  {'CITY': 'Tampa', 'STATE': ' Florida', '1BEDROOM': 1100},
#  {'CITY': 'Austin', 'STATE': ' Texas', '1BEDROOM': 1100},
#  {'CITY': 'Portland', 'STATE': ' Oregon', '1BEDROOM': 1095},
#  {'CITY': 'Anchorage', 'STATE': ' Alaska', '1BEDROOM': 995},
#  {'CITY': 'Sacramento', 'STATE': ' California', '1BEDROOM': 995},
#  {'CITY': 'Virginia Beach', 'STATE': ' Virginia', '1BEDROOM': 975},
#  {'CITY': 'Phoenix', 'STATE': ' Arizona', '1BEDROOM': 909},
#  {'CITY': 'Jacksonville', 'STATE': ' Florida', '1BEDROOM': 896},
#  {'CITY': 'Las Vegas', 'STATE': ' Nevada', '1BEDROOM': 875},
#  {'CITY': 'Newark', 'STATE': ' New Jersey', '1BEDROOM': 850},
#  {'CITY': 'Memphis', 'STATE': ' Tennessee', '1BEDROOM': 835},
#  {'CITY': 'San Antonio', 'STATE': ' Texas', '1BEDROOM': 830},
#  {'CITY': 'Kansas City', 'STATE': ' Missouri', '1BEDROOM': 795},
#  {'CITY': 'Omaha', 'STATE': ' Nebraska', '1BEDROOM': 759},
#  {'CITY': 'Colorado Springs', 'STATE': ' Colorado', '1BEDROOM': 750},
#  {'CITY': 'Milwaukee', 'STATE': ' Wisconsin', '1BEDROOM': 750},
#  {'CITY': 'Louisville', 'STATE': ' Kentucky', '1BEDROOM': 750},
#  {'CITY': 'Columbus', 'STATE': ' Ohio', '1BEDROOM': 750},
#  {'CITY': 'Indianapolis', 'STATE': ' Indiana', '1BEDROOM': 732},
#  {'CITY': 'Albuquerque', 'STATE': ' New Mexico', '1BEDROOM': 715},
#  {'CITY': 'St. Louis', 'STATE': ' Missouri', '1BEDROOM': 700},
#  {'CITY': 'Oklahoma City', 'STATE': ' Oklahoma', '1BEDROOM': 650},
#  {'CITY': 'El Paso', 'STATE': ' Texas', '1BEDROOM': 600},
#  {'CITY': 'Tuscon', 'STATE': ' Arizona', '1BEDROOM': 560},
#  {'CITY': 'Detroit', 'STATE': ' Michigan', '1BEDROOM': 550},
#  {'CITY': 'Cleveland', 'STATE': ' Ohio', '1BEDROOM': 525},
#  {'CITY': 'Wichita', 'STATE': ' Kansas', '1BEDROOM': 470}]

# %%
#Joined payscale scrpaed data with school region data
Lifestyle_pd = pd.merge(Pay_Sch_Reg, apt_info, how='left', on=['STATE'])
Lifestyle_pd

for x in Pay_Sch_Reg['STATE']:
    if apt_info['STATE'] == Pay_Sch_Reg['STATE']:
        append.apt_info['1BEDROOM']
