# %%
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pandas as pd

# %%
csv = "recommendation.csv"
df = pd.read_csv(csv, encoding="ISO-8859-1")
df.shape
# Out:
# (145, 14)

# %%
df['School ID'] = df['Unnamed: 0']
new_df = df.drop(['Unnamed: 0'],axis=1)

# %%
new_df = new_df.replace(['Southern','Midwestern', 'Western', 'California', 'Northeastern' ], [0,1,2,3,4])
new_df[['School ID', 'REGION']] = new_df[['School ID', 'REGION']].apply(pd.to_numeric, errors='coerce')

# %%
new_df.head(10)
# Out:
#                                  School Name  Starting Median Salary  \
# 0                     University of Oklahoma                 44700.0
# 1                  Oklahoma State University                 42800.0
# 2  University of Louisiana (UL) at Lafayette                 41100.0
# 3            University of Colorado   Denver                 46100.0
# 4                           Regis University                 48300.0
# 5                        University of Akron                 41100.0
# 6    Southern Illinois University Carbondale                 43000.0
# 7      San Francisco State University (SFSU)                 47300.0
# 8                      Georgetown University                 55000.0
# 9         George Washington University (GWU)                 47000.0
#
#    Mid-Career Median Salary  Mid-Career 90th Percentile Salary   MORTGAGE  \
# 0                   82900.0                           167000.0   247758.0
# 1                   80700.0                           151000.0   247758.0
# 2                   76300.0                           163000.0   259903.0
# 3                   84400.0                           144000.0   463245.0
# 4                   73800.0                           117000.0   463245.0
# 5                   70300.0                           127000.0   343877.0
# 6                   72500.0                           139000.0   285928.0
# 7                   86400.0                           150000.0  1146835.0
# 8                  110000.0                           248000.0   859866.0
# 9                   97900.0                           194000.0   859866.0
#
#       RENT  ELECTRICITY   GAS  EAT-IN   PHONE  HLTH & WELL    VET  REGION  \
# 0   776.12       154.08  2.18   13.32  164.24       680.75  46.79       0
# 1   776.12       154.08  2.18   13.32  164.24       680.75  46.79       0
# 2   814.16       183.42  2.50   14.38  195.52       654.49  48.02       0
# 3  1451.00       156.76  2.75   14.37  167.10       790.34  55.28       2
# 4  1451.00       156.76  2.75   14.37  167.10       790.34  55.28       2
# 5  1077.00       162.63  2.85   14.90  173.36       631.23  43.29       1
# 6   895.69       161.29  2.68   14.33  171.93       759.56  49.46       1
# 7  3593.00       182.92  3.51   18.87  194.98       901.42  62.84       3
# 8  2694.00       162.13  2.73   16.14  172.82       724.30  50.44       0
# 9  2694.00       162.13  2.73   16.14  172.82       724.30  50.44       0
#
#    School ID
# 0          0
# 1          1
# 2          3
# 3          4
# 4          5
# 5          7
# 6          8
# 7          9
# 8         10
# 9         11

# %%
edited_df = new_df.drop(['School Name'], axis=1)
edited_df = edited_df.astype('int32')
edited_df.head()
# Out:
#    Starting Median Salary  Mid-Career Median Salary  \
# 0                   44700                     82900
# 1                   42800                     80700
# 2                   41100                     76300
# 3                   46100                     84400
# 4                   48300                     73800
#
#    Mid-Career 90th Percentile Salary  MORTGAGE  RENT  ELECTRICITY  GAS  \
# 0                             167000    247758   776          154    2
# 1                             151000    247758   776          154    2
# 2                             163000    259903   814          183    2
# 3                             144000    463245  1451          156    2
# 4                             117000    463245  1451          156    2
#
#    EAT-IN  PHONE  HLTH & WELL  VET  REGION  School ID
# 0      13    164          680   46       0          0
# 1      13    164          680   46       0          1
# 2      14    195          654   48       0          3
# 3      14    167          790   55       2          4
# 4      14    167          790   55       2          5

# %%
X = edited_df
y = edited_df

X.dtypes
# Out:
# Starting Median Salary               int32
# Mid-Career Median Salary             int32
# Mid-Career 90th Percentile Salary    int32
# MORTGAGE                             int32
# RENT                                 int32
# ELECTRICITY                          int32
# GAS                                  int32
# EAT-IN                               int32
# PHONE                                int32
# HLTH & WELL                          int32
# VET                                  int32
# REGION                               int32
# School ID                            int32
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (116, 13) (116, 13)
# (29, 13) (29, 13)

# %%
n_users = edited_df['School ID'].unique().shape[0]
n_items = edited_df.REGION.unique().shape[0]
n_users
n_items
# Out:
# 5

# %%
data_matrix = np.zeros((n_users, n_items))

for line in edited_df.itertuples():
    data_matrix[line[1]-1, line[2]-1] = line[3]
# Out:
# ----------------------------------------------------------------
# IndexError                     Traceback (most recent call last)
# <ipython-input-10-89bcf0cd7811> in <module>
#       2
#       3 for line in edited_df.itertuples():
# ----> 4     data_matrix[line[1]-1, line[2]-1] = line[3]
#
# IndexError: index 44699 is out of bounds for axis 0 with size 145
