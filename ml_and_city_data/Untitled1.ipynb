# %%
import pandas as pd

# %%
csv = "Final_with_School_names.csv"
df = pd.read_csv(csv, encoding="ISO-8859-1")
df
# Out:
#      Unnamed: 0                                     School Name  \
# 0             0                          University of Oklahoma
# 1             1                       Oklahoma State University
# 2             2       University of Louisiana (UL) at Lafayette
# 3             3                 University of Colorado   Denver
# 4             4                                Regis University
# 5             5                             University of Akron
# 6             6         Southern Illinois University Carbondale
# 7             7           San Francisco State University (SFSU)
# 8             8                           Georgetown University
# 9             9              George Washington University (GWU)
# 10           10            American University, Washington D.C.
# 11           11                               Howard University
# 12           12                               Baylor University
# 13           13                              University of Utah
# ...

# %%
southern_df = df.loc[df['REGION'] == 'Southern']

southern_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, School Name, Starting Median Salary, Mid-Career Median Salary, Mid-Career 90th Percentile Salary, MORTGAGE, RENT, ELECTRICITY, GAS, EAT-IN, PHONE, HLTH & WELL, VET, REGION, School ID]
# Index: []
