# 140  48.79                   Kansas-State-University-(KSU)    Midwestern
# 141  52.55      University-of-California,-San-Diego-(UCSD)    California
# 142  52.55               San-Diego-State-University-(SDSU)    California
# 143  47.56        University-of-Wisconsin-(UW)---Green-Bay    Midwestern
# 144  48.90                          University-of-Michigan    Midwestern
# 145  48.54                           Colorado-College-(CC)       Western
# 146  43.29                           Kent-State-University    Midwestern
# 147  59.09                         Northwestern-University    Midwestern
# 148  54.61          University-of-Wisconsin-(UW)---Madison    Midwestern
# 149  55.12       University-of-Alabama-at-Huntsville-(UAH)      Southern
# 150  69.64                   University-of-Washington-(UW)       Western
# 151  69.64                              Seattle-University       Western
# 152  62.69              University-of-California,-Berkeley    California
# 153  45.04           University-of-Texas-at-El-Paso-(UTEP)      Southern
# 154  48.90                             Mississippi-College      Southern
# 155  45.91                 Arkansas-State-University-(ASU)      Southern
# 156  59.86                    University-of-Virginia-(UVA)      Southern
# 157  51.06                  Florida-State-University-(FSU)      Southern
# 158  60.58   Wesleyan-University-(Middletown,-Connecticut)  Northeastern
# 159  50.23                   Eastern-Washington-University       Western
# 160  55.18                              Widener-University  Northeastern
# 161  53.22                          University-of-Nebraska    Midwestern
# 162  50.23                                Lamar-University      Southern
# 163  51.83              Tennessee-Technological-University      Southern
# 164  56.15  California-State-University,-Sacramento-(CSUS)    California
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $44,700.00-              $82,900.00-
# 1              $42,800.00-              $80,700.00-
# 2              $40,000.00-              $64,300.00-
# 3              $41,100.00-              $76,300.00-
# 4              $46,100.00-              $84,400.00-
# 5              $48,300.00-              $73,800.00-
# 6              $75,500.00-             $123,000.00-
# 7              $41,100.00-              $70,300.00-
# 8              $43,000.00-              $72,500.00-
# 9              $47,300.00-              $86,400.00-
# 10             $55,000.00-             $110,000.00-
# 11             $47,000.00-              $97,900.00-
# 12             $45,300.00-              $90,800.00-
# 13             $46,900.00-              $81,800.00-
# 14             $48,300.00-              $88,600.00-
# 15             $45,400.00-              $83,200.00-
# 16             $45,700.00-              $74,000.00-
# 17             $70,400.00-             $129,000.00-
# 18             $46,600.00-              $81,500.00-
# 19             $46,500.00-              $82,900.00-
# 20             $42,100.00-              $80,000.00-
# 21             $44,900.00-              $76,000.00-
# 22             $53,000.00-              $96,700.00-
# 23             $49,000.00-              $93,900.00-
# 24             $50,500.00-              $86,400.00-
# 25             $45,600.00-              $78,200.00-
# 26             $42,100.00-              $74,000.00-
# 27             $42,800.00-              $76,100.00-
# 28             $45,200.00-              $71,600.00-
# 29             $39,200.00-              $70,100.00-
# ..                     ...                      ...
# 135            $48,600.00-             $101,000.00-
# 136            $41,100.00-              $71,100.00-
# 137            $47,500.00-              $86,100.00-
# 138            $47,000.00-              $77,800.00-
# 139            $45,400.00-              $84,600.00-
# 140            $43,300.00-              $79,000.00-
# 141            $51,100.00-             $101,000.00-
# 142            $46,200.00-              $85,200.00-
# 143            $35,800.00-              $60,600.00-
# 144            $52,700.00-              $93,000.00-
# 145            $38,500.00-              $81,400.00-
# 146            $38,700.00-              $62,600.00-
# 147            $52,700.00-              $95,900.00-
# 148            $48,900.00-              $87,800.00-
# 149            $43,100.00-              $82,700.00-
# 150            $48,800.00-              $85,300.00-
# 151            $48,300.00-              $82,800.00-
# 152            $59,900.00-             $112,000.00-
# 153            $43,400.00-              $72,100.00-
# 154            $35,400.00-              $60,400.00-
# 155            $38,700.00-              $63,300.00-
# 156            $52,700.00-             $103,000.00-
# 157            $42,100.00-              $73,000.00-
# 158            $46,500.00-              $97,900.00-
# 159            $38,600.00-              $70,900.00-
# 160            $52,900.00-              $83,400.00-
# 161            $45,700.00-              $80,900.00-
# 162            $46,500.00-              $79,400.00-
# 163            $46,200.00-              $80,000.00-
# 164            $47,800.00-              $82,400.00-
#
#     Mid-Career 90th Percentile Salary
# 0                        $167,000.00-
# 1                        $151,000.00-
# 2                                 NaN
# 3                        $163,000.00-
# 4                        $144,000.00-
# 5                        $117,000.00-
# 6                                 NaN
# 7                        $127,000.00-
# 8                        $139,000.00-
# 9                        $150,000.00-
# 10                       $248,000.00-
# 11                       $194,000.00-
# 12                       $169,000.00-
# 13                       $138,000.00-
# 14                       $200,000.00-
# 15                       $148,000.00-
# 16                       $150,000.00-
# 17                       $257,000.00-
# 18                       $137,000.00-
# 19                       $143,000.00-
# 20                       $160,000.00-
# 21                       $138,000.00-
# 22                       $153,000.00-
# 23                       $193,000.00-
# 24                       $159,000.00-
# 25                       $151,000.00-
# 26                       $145,000.00-
# 27                       $139,000.00-
# 28                       $128,000.00-
# 29                       $125,000.00-
# ..                                ...
# 135                               NaN
# 136                      $131,000.00-
# 137                      $160,000.00-
# 138                      $130,000.00-
# 139                      $147,000.00-
# 140                      $138,000.00-
# 141                      $177,000.00-
# 142                      $158,000.00-
# 143                      $102,000.00-
# 144                      $182,000.00-
# 145                               NaN
# 146                      $124,000.00-
# 147                      $205,000.00-
# 148                      $170,000.00-
# 149                      $132,000.00-
# 150                      $149,000.00-
# 151                      $150,000.00-
# 152                      $201,000.00-
# 153                      $133,000.00-
# 154                               NaN
# 155                      $118,000.00-
# 156                      $215,000.00-
# 157                      $156,000.00-
# 158                      $215,000.00-
# 159                      $117,000.00-
# 160                      $138,000.00-
# 161                      $156,000.00-
# 162                      $158,000.00-
# 163                      $121,000.00-
# 164                      $154,000.00-
#
# [165 rows x 13 columns]

# %%
df = df.drop(['School Name'],axis=1)

# %%
df.dtypes
# Out:
# MORTGAGE                             float64
# RENT                                 float64
# ELECTRICITY                          float64
# GAS                                  float64
# EAT-IN                               float64
# PHONE                                float64
# HLTH & WELL                          float64
# VET                                  float64
# REGION                                object
# Starting Median Salary                object
# Mid-Career Median Salary              object
# Mid-Career 90th Percentile Salary     object
# dtype: object

# %%
df['Starting Median Salary'] = df['Starting Median Salary'].str.replace('$', '')
df['Starting Median Salary'] = df['Starting Median Salary'].str.replace('-', '')

df['Mid-Career Median Salary'] = df['Mid-Career Median Salary'].str.replace('$', '')
df['Mid-Career Median Salary'] = df['Mid-Career Median Salary'].str.replace('-', '')

df['Mid-Career 90th Percentile Salary'] = df['Mid-Career 90th Percentile Salary'].str.replace('$', '')
df['Mid-Career 90th Percentile Salary'] = df['Mid-Career 90th Percentile Salary'].str.replace('-', '')

# %%
df.columns = pd.to_numeric()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-92c2eb289b02> in <module>
# ----> 1 df.columns = pd.to_numeric()
#
# TypeError: to_numeric() missing 1 required positional argument: 'arg'

# %%
df = df[['Starting Median Salary', 'Mid-Career Median Salary', 'Mid-Career 90th Percentile Salary', 'MORTGAGE',\
        'RENT', 'ELECTRICITY', 'GAS', 'EAT-IN','PHONE', 'HLTH & WELL', 'VET', 'REGION']]
df = df.dropna()
df
# Out:
#     Starting Median Salary Mid-Career Median Salary  \
# 0                44,700.00                82,900.00
# 1                42,800.00                80,700.00
# 3                41,100.00                76,300.00
# 4                46,100.00                84,400.00
# 5                48,300.00                73,800.00
# 7                41,100.00                70,300.00
# 8                43,000.00                72,500.00
# 9                47,300.00                86,400.00
# 10               55,000.00               110,000.00
# 11               47,000.00                97,900.00
# 12               45,300.00                90,800.00
# 13               46,900.00                81,800.00
# 14               48,300.00                88,600.00
# 15               45,400.00                83,200.00
# 16               45,700.00                74,000.00
# 17               70,400.00               129,000.00
# 18               46,600.00                81,500.00
# 19               46,500.00                82,900.00
# 20               42,100.00                80,000.00
# 21               44,900.00                76,000.00
# 22               53,000.00                96,700.00
# 23               49,000.00                93,900.00
# 24               50,500.00                86,400.00
# 25               45,600.00                78,200.00
# 26               42,100.00                74,000.00
# 27               42,800.00                76,100.00
# 28               45,200.00                71,600.00
# 29               39,200.00                70,100.00
# 30               39,500.00                63,900.00
# 31               41,800.00                71,400.00
# ..                     ...                      ...
# 130              61,800.00               111,000.00
# 131              40,700.00                84,400.00
# 133              44,100.00                82,800.00
# 136              41,100.00                71,100.00
# 137              47,500.00                86,100.00
# 138              47,000.00                77,800.00
# 139              45,400.00                84,600.00
# 140              43,300.00                79,000.00
# 141              51,100.00               101,000.00
# 142              46,200.00                85,200.00
# 143              35,800.00                60,600.00
# 144              52,700.00                93,000.00
# 146              38,700.00                62,600.00
# 147              52,700.00                95,900.00
# 148              48,900.00                87,800.00
# 149              43,100.00                82,700.00
# 150              48,800.00                85,300.00
# 151              48,300.00                82,800.00
# 152              59,900.00               112,000.00
# 153              43,400.00                72,100.00
# 155              38,700.00                63,300.00
# 156              52,700.00               103,000.00
# 157              42,100.00                73,000.00
# 158              46,500.00                97,900.00
# 159              38,600.00                70,900.00
# 160              52,900.00                83,400.00
# 161              45,700.00                80,900.00
# 162              46,500.00                79,400.00
# 163              46,200.00                80,000.00
# 164              47,800.00                82,400.00
#
#     Mid-Career 90th Percentile Salary   MORTGAGE     RENT  ELECTRICITY   GAS  \
# 0                          167,000.00   247758.0   776.12       154.08  2.18
# 1                          151,000.00   247758.0   776.12       154.08  2.18
# 3                          163,000.00   259903.0   814.16       183.42  2.50
# 4                          144,000.00   463245.0  1451.00       156.76  2.75
# 5                          117,000.00   463245.0  1451.00       156.76  2.75
# 7                          127,000.00   343877.0  1077.00       162.63  2.85
# 8                          139,000.00   285928.0   895.69       161.29  2.68
# 9                          150,000.00  1146835.0  3593.00       182.92  3.51
# 10                         248,000.00   859866.0  2694.00       162.13  2.73
# 11                         194,000.00   859866.0  2694.00       162.13  2.73
# 12                         169,000.00   859866.0  2694.00       162.13  2.73
# 13                         138,000.00   859866.0  2694.00       162.13  2.73
# 14                         200,000.00   282805.0   885.91       177.55  2.53
# 15                         148,000.00   320281.0  1003.00       130.77  2.80
# 16                         150,000.00   321322.0  1007.00       199.68  2.76
# 17                         257,000.00  2140883.0  6706.00       181.74  3.16
# 18                         137,000.00   337631.0  1058.00       190.63  2.54
# 19                         143,000.00   370596.0  1161.00       141.84  2.95
# 20                         160,000.00   828384.0  2595.00       208.74  3.00
# 21                         138,000.00   320281.0  1003.00       126.75  2.93
# 22                         153,000.00   717943.0  2249.00       236.57  2.89
# 23                         193,000.00   717943.0  2249.00       236.57  2.89
# 24                         159,000.00   717943.0  2249.00       236.57  2.89
# 25                         151,000.00   717943.0  2249.00       236.57  2.89
# 26                         145,000.00   717943.0  2249.00       236.57  2.89
# 27                         139,000.00   326527.0  1023.00       171.18  2.82
# 28                         128,000.00   376148.0  1178.00       151.23  2.96
# 29                         125,000.00   299808.0   939.17       169.00  2.38
# 30                         120,000.00   343530.0  1076.00       179.56  3.40
# 31                         126,000.00   268231.0   840.25       144.19  2.68
# ..                                ...        ...      ...          ...   ...
# 130                        209,000.00   317505.0   994.61       184.43  2.78
# 131                        131,000.00   317505.0   994.61       184.43  2.78
# 133                        160,000.00   263026.0   823.95       158.61  2.22
# 136                        131,000.00   266843.0   835.90       194.99  2.77
# 137                        160,000.00   277600.0   869.60       151.23  2.52
# 138                        130,000.00   509743.0  1597.00       179.56  2.69
# 139                        147,000.00   331038.0  1037.00       133.63  2.79
# 140                        138,000.00   294256.0   921.78       149.39  2.39
# 141                        177,000.00   817185.0  2560.00       192.64  3.36
# 142                        158,000.00   817185.0  2560.00       192.64  3.36
# 143                        102,000.00   281070.0   880.47       172.86  2.62
# 144                        182,000.00   407378.0  1276.00       157.10  2.57
# 146                        124,000.00   546401.0  1712.00       162.63  2.85
# 147                        205,000.00   854777.0  2678.00       151.23  3.30
# 148                        170,000.00   379618.0  1189.00       176.38  2.80
# 149                        132,000.00   258168.0   808.73       183.92  2.49
# 150                        149,000.00   673874.0  2111.00       206.39  3.47
# 151                        150,000.00   673874.0  2111.00       206.39  3.47
# 152                        201,000.00  1128030.0  3534.00       190.46  3.40
# 153                        133,000.00   271701.0   851.12       155.25  2.66
# 155                        118,000.00   257821.0   807.64       146.03  2.26
# 156                        215,000.00   376495.0  1179.00       159.11  2.24
# 157                        156,000.00   315423.0   988.08       144.36  2.43
# 158                        215,000.00   616230.0  1930.00       161.62  2.94
# 159                        117,000.00   336194.0  1053.00       126.75  2.93
# 160                        138,000.00   244957.0   767.34       208.74  3.00
# 161                        156,000.00   286622.0   897.86       120.21  2.66
# 162                        158,000.00   311953.0   977.21       216.11  2.47
# 163                        121,000.00   237695.0   744.60       166.99  2.26
# 164                        154,000.00   474696.0  1487.00       149.72  3.20
#
#      EAT-IN   PHONE  HLTH & WELL    VET        REGION
# 0     13.32  164.24       680.75  46.79      Southern
# 1     13.32  164.24       680.75  46.79      Southern
# 3     14.38  195.52       654.49  48.02      Southern
# 4     14.37  167.10       790.34  55.28       Western
# 5     14.37  167.10       790.34  55.28       Western
# 7     14.90  173.36       631.23  43.29    Midwestern
# 8     14.33  171.93       759.56  49.46    Midwestern
# 9     18.87  194.98       901.42  62.84    California
# 10    16.14  172.82       724.30  50.44      Southern
# 11    16.14  172.82       724.30  50.44      Southern
# 12    16.14  172.82       724.30  50.44      Southern
# 13    16.14  172.82       724.30  50.44      Southern
# 14    12.14  189.26       695.78  49.00      Southern
# 15    14.31  139.40       695.78  49.26       Western
# 16    14.51  212.86       662.74  50.90  Northeastern
# 17    21.68  193.73      1017.01  65.26    California
# 18    16.14  203.20       914.18  59.65       Western
# 19    14.68  151.20       827.11  58.21       Western
# 20    17.05  222.51       793.34  55.18  Northeastern
# 21    14.23  135.11       851.89  50.23       Western
# 22    15.52  252.17      1014.76  66.81  Northeastern
# 23    15.52  252.17      1014.76  66.81  Northeastern
# 24    15.52  252.17      1014.76  66.81  Northeastern
# 25    15.52  252.17      1014.76  66.81  Northeastern
# 26    15.52  252.17      1014.76  66.81  Northeastern
# 27    13.32  182.47       707.02  50.03    Midwestern
# 28    15.26  161.21       770.83  51.52       Western
# 29    14.02  180.15       628.96  47.20      Southern
# 30    15.79  191.41       884.91  49.77       Western
# 31    16.71  153.70       875.16  52.91    Midwestern
# ..      ...     ...          ...    ...           ...
# 130   16.21  196.59       704.03  50.13  Northeastern
# 131   16.21  196.59       704.03  50.13  Northeastern
# 133   13.70  169.07       663.50  50.49      Southern
# 136   14.68  207.85       737.80  49.93      Southern
# 137   15.07  161.21       759.56  52.14       Western
# 138   15.74  191.41       687.52  54.40      Southern
# 139   13.32  142.44       748.31  46.22    Midwestern
# 140   13.84  159.24       710.03  48.79    Midwestern
# 141   16.57  205.35       806.85  52.55    California
# 142   16.57  205.35       806.85  52.55    California
# 143   13.37  184.26       780.58  47.56    Midwestern
# 144   16.20  167.46       935.20  48.90    Midwestern
# 146   14.90  173.36       631.23  43.29    Midwestern
# 147   15.89  161.21       760.32  59.09    Midwestern
# 148   15.11  188.01       918.68  54.61    Midwestern
# 149   14.10  196.06       725.05  55.12      Southern
# 150   18.60  220.00       932.20  69.64       Western
# 151   18.60  220.00       932.20  69.64       Western
# 152   18.42  203.03       923.93  62.69    California
# 153   15.28  165.49       726.55  45.04      Southern
# 155   13.30  155.67       613.21  45.91      Southern
# 156   15.52  169.61       829.37  59.86      Southern
# 157   16.13  153.88       739.30  51.06      Southern
# 158   14.77  172.29       852.64  60.58  Northeastern
# 159   14.23  135.11       851.89  50.23       Western
# 160   17.05  222.51       793.34  55.18  Northeastern
# 161   14.12  128.14       768.57  53.22    Midwestern
# 162   13.19  230.37       683.01  50.23      Southern
# 163   12.57  178.01       672.51  51.83      Southern
# 164   17.13  159.60       778.34  56.15    California
#
# [145 rows x 12 columns]

# %%
X = df.drop('REGION', axis=1)
y = df['REGION']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-40d1881acb7d> in <module>
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 classifier = DecisionTreeClassifier()
# ----> 3 classifier.fit(X_train, y_train)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     114         random_state = check_random_state(self.random_state)
#     115         if check_input:
# --> 116             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     117             y = check_array(y, ensure_2d=False, dtype=None)
#     118             if issparse(X):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: '52,900.00'

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
